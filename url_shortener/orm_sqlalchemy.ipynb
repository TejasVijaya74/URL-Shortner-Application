# %% [markdown]
# Cell 1 – Setup

# %%
from models import db, URL
from app import app

# %% [markdown]
#  Cell 2 – View All URLs

# %%
with app.app_context():
    urls = URL.query.all()
    for u in urls:
        print(u.original_url, u.short_code)

# %% [markdown]
# Cell 3 – Add Sample Data

# %%
with app.app_context():
    sample = URL(original_url="https://example.com", short_code="ex123")
    db.session.add(sample)
    db.session.commit()
